# %%
import matplotlib.pyplot as plt

# %%
x=range(0,10)

# %%
y=[23,34,56,67,78,23,45,12,45,5]

# %%
plt.plot(x,y)

# %%
plt.xlabel("my x label is nice")

# %%
plt.ylabel("my y label is cool")

# %%
plt.title("my title is wonderful")

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
plt.plot(x,y)

# %%
plt.show()
